# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
from sqlalchemy import *
import pandas as pd
import re
from nltk import word_tokenize
import nltk
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,AdaBoostClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, f1_score, fbeta_score, classification_report
from scipy.stats import hmean
from scipy.stats.mstats import gmean

nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\amrhw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\amrhw\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\amrhw\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
# load data from database
engine = create_engine('sqlite:///messages.db')
df = pd.read_sql('SELECT * FROM messages',engine)
df.head()
X = df['message']
Y = df.iloc[:,4:]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
        
    detected_url=re.findall(url_regex,text)
    for url in detected_url:
        text.replace(url,'urlplaceholder')
    tokens=word_tokenize(text)
    lemmitizer=WordNetLemmatizer()
    clean_tokens=[]
    for tok in tokens:
        clean_tok=lemmitizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)
    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
def build_pipeline():
    
    pipeline = Pipeline([('features',FeatureUnion(
        [
            ('text_pipeline',Pipeline(
            [   ('vect',CountVectorizer(tokenizer=tokenize)),
                ('tfidf',TfidfTransformer())
            ]))
        ]
        )),
        ('clf', MultiOutputClassifier(AdaBoostClassifier()))
                        ])
    return pipeline

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)

model=build_pipeline()
model.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('features',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('text_pipeline',
#                                                  Pipeline(memory=None,
#                                                           steps=[('vect',
#                                                                   CountVectorizer(analyzer='word',
#                                                                                   binary=False,
#                                                                                   decode_error='strict',
#                                                                                   dtype=<class 'numpy.int64'>,
#                                                                                   encoding='utf-8',
#                                                                                   input='content',
#                                                                                   lowercase=True,
#                                                                                   max_df=1.0,
#                                                                                   max_features=None,
#                                                                                   min_df=1,
#                                                                                   ngram_range=(1,
#                                                                                                1),
#                                                                                   preprocessor=Non...
#                                                                                   tokenizer=<function tokenize at 0x0000023870C71B88>,
#                                                                                   vocabulary=None)),
#                                                                  ('tfidf',
#                                                                   TfidfTransformer(norm='l2',
#                                                                                    smooth_idf=True,
#                                                                                    sublinear_tf=False,
#                                                                                    use_idf=True))],
#                                                           verbose=False))],
#                               transformer_weights=None, verbose=False)),
#                 ('clf',
#                  MultiOutputClassifier(estimator=AdaBoostClassifier(algorithm='SAMME.R',
#                                                                     base_estimator=None,
#                                                                     learning_rate=1.0,
#                                                                     n_estimators=50,
#                                                                     random_state=None),
#                                        n_jobs=None))],
#          verbose=False)

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
msg = ['Hello I see fire in the street and many houses are destroyed, homeless people everywhere']

test=model.predict(msg)
print(y_train.columns.values[test.flatten()==1])
y_pred = model.predict(X_test)


overall_accuracy = (y_pred == y_test).mean().mean()

print('Average overall accuracy {0:.2f}% \n'.format(overall_accuracy*100))

y_pred_pd = pd.DataFrame(y_pred, columns = y_test.columns)
for column in y_test.columns:
    print('------------------------------------------------------\n')
    print('FEATURE: {}\n'.format(column))
    print(classification_report(y_test[column],y_pred_pd[column]))
# Out:
# ['related' 'request' 'aid_related' 'shelter' 'buildings' 'weather_related'
#  'fire' 'direct_report']
# Average overall accuracy 94.69%
#
# ------------------------------------------------------
#
# FEATURE: related
#
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.25      0.34      1513
#          1.0       0.80      0.93      0.86      4988
#          2.0       0.25      0.09      0.14        53
#
#     accuracy                           0.77      6554
#    macro avg       0.53      0.43      0.45      6554
# weighted avg       0.73      0.77      0.73      6554
#
# ------------------------------------------------------
#
# FEATURE: request
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.97      0.94      5444
#          1.0       0.79      0.56      0.65      1110
#
#     accuracy                           0.90      6554
#    macro avg       0.85      0.76      0.80      6554
# weighted avg       0.89      0.90      0.89      6554
#
# ------------------------------------------------------
#
# FEATURE: offer
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6521
#          1.0       0.08      0.03      0.04        33
#
#     accuracy                           0.99      6554
#    macro avg       0.54      0.51      0.52      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: aid_related
#
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.88      0.81      3810
#          1.0       0.78      0.59      0.67      2744
#
#     accuracy                           0.76      6554
#    macro avg       0.77      0.74      0.74      6554
# weighted avg       0.76      0.76      0.75      6554
#
# ------------------------------------------------------
#
# FEATURE: medical_help
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96      6050
#          1.0       0.57      0.26      0.35       504
#
#     accuracy                           0.93      6554
#    macro avg       0.75      0.62      0.66      6554
# weighted avg       0.91      0.93      0.91      6554
#
# ------------------------------------------------------
#
# FEATURE: medical_products
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      6202
#          1.0       0.70      0.34      0.46       352
#
#     accuracy                           0.96      6554
#    macro avg       0.83      0.67      0.72      6554
# weighted avg       0.95      0.96      0.95      6554
#
# ------------------------------------------------------
#
# FEATURE: search_and_rescue
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6387
#          1.0       0.57      0.18      0.27       167
#
#     accuracy                           0.98      6554
#    macro avg       0.77      0.59      0.63      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ------------------------------------------------------
#
# FEATURE: security
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6436
#          1.0       0.26      0.06      0.10       118
#
#     accuracy                           0.98      6554
#    macro avg       0.62      0.53      0.54      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ------------------------------------------------------
#
# FEATURE: military
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      6340
#          1.0       0.64      0.35      0.45       214
#
#     accuracy                           0.97      6554
#    macro avg       0.81      0.67      0.72      6554
# weighted avg       0.97      0.97      0.97      6554
#
# ------------------------------------------------------
#
# FEATURE: child_alone
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# ------------------------------------------------------
#
# FEATURE: water
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      6115
#          1.0       0.77      0.60      0.67       439
#
#     accuracy                           0.96      6554
#    macro avg       0.87      0.79      0.83      6554
# weighted avg       0.96      0.96      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: food
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97      5777
#          1.0       0.82      0.71      0.76       777
#
#     accuracy                           0.95      6554
#    macro avg       0.89      0.84      0.87      6554
# weighted avg       0.95      0.95      0.95      6554
#
# ------------------------------------------------------
#
# FEATURE: shelter
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97      5955
#          1.0       0.77      0.49      0.60       599
#
#     accuracy                           0.94      6554
#    macro avg       0.86      0.74      0.78      6554
# weighted avg       0.93      0.94      0.93      6554
#
# ------------------------------------------------------
#
# FEATURE: clothing
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6446
#          1.0       0.68      0.35      0.46       108
#
#     accuracy                           0.99      6554
#    macro avg       0.83      0.67      0.73      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: money
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6405
#          1.0       0.64      0.30      0.40       149
#
#     accuracy                           0.98      6554
#    macro avg       0.81      0.65      0.70      6554
# weighted avg       0.98      0.98      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: missing_people
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6481
#          1.0       0.57      0.16      0.26        73
#
#     accuracy                           0.99      6554
#    macro avg       0.78      0.58      0.62      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: refugees
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      6322
#          1.0       0.55      0.21      0.31       232
#
#     accuracy                           0.97      6554
#    macro avg       0.76      0.60      0.64      6554
# weighted avg       0.96      0.97      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: death
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98      6264
#          1.0       0.77      0.48      0.59       290
#
#     accuracy                           0.97      6554
#    macro avg       0.87      0.74      0.79      6554
# weighted avg       0.97      0.97      0.97      6554
#
# ------------------------------------------------------
#
# FEATURE: other_aid
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93      5669
#          1.0       0.54      0.14      0.22       885
#
#     accuracy                           0.87      6554
#    macro avg       0.71      0.56      0.58      6554
# weighted avg       0.83      0.87      0.83      6554
#
# ------------------------------------------------------
#
# FEATURE: infrastructure_related
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.96      6121
#          1.0       0.43      0.11      0.17       433
#
#     accuracy                           0.93      6554
#    macro avg       0.69      0.55      0.57      6554
# weighted avg       0.91      0.93      0.91      6554
#
# ------------------------------------------------------
#
# FEATURE: transport
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      6216
#          1.0       0.72      0.20      0.31       338
#
#     accuracy                           0.95      6554
#    macro avg       0.84      0.60      0.65      6554
# weighted avg       0.95      0.95      0.94      6554
#
# ------------------------------------------------------
#
# FEATURE: buildings
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      6219
#          1.0       0.71      0.41      0.52       335
#
#     accuracy                           0.96      6554
#    macro avg       0.84      0.70      0.75      6554
# weighted avg       0.96      0.96      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: electricity
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6417
#          1.0       0.69      0.24      0.36       137
#
#     accuracy                           0.98      6554
#    macro avg       0.84      0.62      0.67      6554
# weighted avg       0.98      0.98      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: tools
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6514
#          1.0       0.00      0.00      0.00        40
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: hospitals
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6486
#          1.0       0.30      0.10      0.15        68
#
#     accuracy                           0.99      6554
#    macro avg       0.65      0.55      0.57      6554
# weighted avg       0.98      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: shops
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6521
#          1.0       0.00      0.00      0.00        33
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: aid_centers
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6461
#          1.0       0.33      0.03      0.06        93
#
#     accuracy                           0.99      6554
#    macro avg       0.66      0.52      0.53      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: other_infrastructure
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      6270
#          1.0       0.46      0.11      0.18       284
#
#     accuracy                           0.96      6554
#    macro avg       0.71      0.55      0.58      6554
# weighted avg       0.94      0.96      0.94      6554
#
# ------------------------------------------------------
#
# FEATURE: weather_related
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.96      0.91      4676
#          1.0       0.85      0.65      0.74      1878
#
#     accuracy                           0.87      6554
#    macro avg       0.86      0.80      0.82      6554
# weighted avg       0.87      0.87      0.86      6554
#
# ------------------------------------------------------
#
# FEATURE: floods
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      6019
#          1.0       0.84      0.53      0.65       535
#
#     accuracy                           0.95      6554
#    macro avg       0.90      0.76      0.81      6554
# weighted avg       0.95      0.95      0.95      6554
#
# ------------------------------------------------------
#
# FEATURE: storm
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.96      5911
#          1.0       0.78      0.46      0.58       643
#
#     accuracy                           0.93      6554
#    macro avg       0.86      0.72      0.77      6554
# weighted avg       0.93      0.93      0.93      6554
#
# ------------------------------------------------------
#
# FEATURE: fire
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6479
#          1.0       0.53      0.25      0.34        75
#
#     accuracy                           0.99      6554
#    macro avg       0.76      0.63      0.67      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: earthquake
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      5895
#          1.0       0.89      0.75      0.81       659
#
#     accuracy                           0.97      6554
#    macro avg       0.93      0.87      0.90      6554
# weighted avg       0.96      0.97      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: cold
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6419
#          1.0       0.73      0.39      0.51       135
#
#     accuracy                           0.98      6554
#    macro avg       0.86      0.69      0.75      6554
# weighted avg       0.98      0.98      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: other_weather
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97      6195
#          1.0       0.49      0.15      0.23       359
#
#     accuracy                           0.94      6554
#    macro avg       0.72      0.57      0.60      6554
# weighted avg       0.93      0.94      0.93      6554
#
# ------------------------------------------------------
#
# FEATURE: direct_report
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.95      0.92      5279
#          1.0       0.70      0.48      0.57      1275
#
#     accuracy                           0.86      6554
#    macro avg       0.79      0.72      0.74      6554
# weighted avg       0.85      0.86      0.85      6554

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = {
    'features__text_pipeline__vect__ngram_range': ((1, 1), (1, 2)),
    'features__text_pipeline__vect__max_df': (0.75, 1.0),
    'features__text_pipeline__vect__max_features': (None, 5000),
    'features__text_pipeline__tfidf__use_idf': (True, False),    
}

def build_pipeline():
    
    pipeline = Pipeline([('features',FeatureUnion(
        [
            ('text_pipeline',Pipeline(
            [   ('vect',CountVectorizer(tokenizer=tokenize)),
                ('tfidf',TfidfTransformer())
            ])),
            ('verb_extractor',VerbExtractor())
        ]
        )),
        ('clf', MultiOutputClassifier(AdaBoostClassifier()))
                        ])
    return pipeline
cv=GridSearchCV(build_pipeline(),param_grid=parameters,n_jobs=-1)
cv.fit(X_train,y_train)
print(cv.best_params_)
y_pred=cv.predict(X_test)
# Out:
# {'features__text_pipeline__tfidf__use_idf': True, 'features__text_pipeline__vect__max_df': 1.0, 'features__text_pipeline__vect__max_features': None, 'features__text_pipeline__vect__ngram_range': (1, 2)}
# ------------------------------------------------------
#
# FEATURE: related
#
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.25      0.34      1513
#          1.0       0.80      0.93      0.86      4988
#          2.0       0.26      0.15      0.19        53
#
#     accuracy                           0.77      6554
#    macro avg       0.54      0.45      0.47      6554
# weighted avg       0.74      0.77      0.74      6554
#
# ------------------------------------------------------
#
# FEATURE: request
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.96      0.94      5444
#          1.0       0.76      0.57      0.65      1110
#
#     accuracy                           0.90      6554
#    macro avg       0.84      0.76      0.79      6554
# weighted avg       0.89      0.90      0.89      6554
#
# ------------------------------------------------------
#
# FEATURE: offer
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6521
#          1.0       0.20      0.06      0.09        33
#
#     accuracy                           0.99      6554
#    macro avg       0.60      0.53      0.55      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: aid_related
#
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.87      0.81      3810
#          1.0       0.77      0.61      0.69      2744
#
#     accuracy                           0.76      6554
#    macro avg       0.77      0.74      0.75      6554
# weighted avg       0.77      0.76      0.76      6554
#
# ------------------------------------------------------
#
# FEATURE: medical_help
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96      6050
#          1.0       0.55      0.26      0.35       504
#
#     accuracy                           0.93      6554
#    macro avg       0.75      0.62      0.66      6554
# weighted avg       0.91      0.93      0.91      6554
#
# ------------------------------------------------------
#
# FEATURE: medical_products
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      6202
#          1.0       0.67      0.34      0.45       352
#
#     accuracy                           0.96      6554
#    macro avg       0.82      0.66      0.71      6554
# weighted avg       0.95      0.96      0.95      6554
#
# ------------------------------------------------------
#
# FEATURE: search_and_rescue
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6387
#          1.0       0.56      0.18      0.27       167
#
#     accuracy                           0.98      6554
#    macro avg       0.77      0.59      0.63      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ------------------------------------------------------
#
# FEATURE: security
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6436
#          1.0       0.29      0.08      0.13       118
#
#     accuracy                           0.98      6554
#    macro avg       0.63      0.54      0.56      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ------------------------------------------------------
#
# FEATURE: military
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      6340
#          1.0       0.61      0.36      0.45       214
#
#     accuracy                           0.97      6554
#    macro avg       0.79      0.68      0.72      6554
# weighted avg       0.97      0.97      0.97      6554
#
# ------------------------------------------------------
#
# FEATURE: child_alone
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# ------------------------------------------------------
#
# FEATURE: water
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      6115
#          1.0       0.75      0.62      0.68       439
#
#     accuracy                           0.96      6554
#    macro avg       0.86      0.80      0.83      6554
# weighted avg       0.96      0.96      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: food
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97      5777
#          1.0       0.82      0.69      0.75       777
#
#     accuracy                           0.95      6554
#    macro avg       0.89      0.84      0.86      6554
# weighted avg       0.94      0.95      0.94      6554
#
# ------------------------------------------------------
#
# FEATURE: shelter
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97      5955
#          1.0       0.78      0.50      0.61       599
#
#     accuracy                           0.94      6554
#    macro avg       0.86      0.74      0.79      6554
# weighted avg       0.94      0.94      0.93      6554
#
# ------------------------------------------------------
#
# FEATURE: clothing
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6446
#          1.0       0.67      0.38      0.49       108
#
#     accuracy                           0.99      6554
#    macro avg       0.83      0.69      0.74      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: money
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6405
#          1.0       0.59      0.29      0.39       149
#
#     accuracy                           0.98      6554
#    macro avg       0.79      0.64      0.69      6554
# weighted avg       0.97      0.98      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: missing_people
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6481
#          1.0       0.38      0.12      0.19        73
#
#     accuracy                           0.99      6554
#    macro avg       0.68      0.56      0.59      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: refugees
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      6322
#          1.0       0.49      0.22      0.30       232
#
#     accuracy                           0.96      6554
#    macro avg       0.73      0.60      0.64      6554
# weighted avg       0.95      0.96      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: death
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      6264
#          1.0       0.77      0.43      0.55       290
#
#     accuracy                           0.97      6554
#    macro avg       0.87      0.71      0.77      6554
# weighted avg       0.97      0.97      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: other_aid
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93      5669
#          1.0       0.50      0.15      0.23       885
#
#     accuracy                           0.86      6554
#    macro avg       0.69      0.56      0.58      6554
# weighted avg       0.83      0.86      0.83      6554
#
# ------------------------------------------------------
#
# FEATURE: infrastructure_related
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.96      6121
#          1.0       0.42      0.11      0.17       433
#
#     accuracy                           0.93      6554
#    macro avg       0.68      0.55      0.57      6554
# weighted avg       0.91      0.93      0.91      6554
#
# ------------------------------------------------------
#
# FEATURE: transport
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      6216
#          1.0       0.62      0.26      0.36       338
#
#     accuracy                           0.95      6554
#    macro avg       0.79      0.62      0.67      6554
# weighted avg       0.94      0.95      0.94      6554
#
# ------------------------------------------------------
#
# FEATURE: buildings
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      6219
#          1.0       0.69      0.43      0.53       335
#
#     accuracy                           0.96      6554
#    macro avg       0.83      0.71      0.75      6554
# weighted avg       0.96      0.96      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: electricity
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6417
#          1.0       0.71      0.33      0.45       137
#
#     accuracy                           0.98      6554
#    macro avg       0.85      0.66      0.72      6554
# weighted avg       0.98      0.98      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: tools
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6514
#          1.0       0.00      0.00      0.00        40
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: hospitals
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6486
#          1.0       0.18      0.09      0.12        68
#
#     accuracy                           0.99      6554
#    macro avg       0.59      0.54      0.56      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: shops
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6521
#          1.0       0.00      0.00      0.00        33
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: aid_centers
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6461
#          1.0       0.19      0.05      0.08        93
#
#     accuracy                           0.98      6554
#    macro avg       0.59      0.53      0.54      6554
# weighted avg       0.98      0.98      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: other_infrastructure
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      6270
#          1.0       0.39      0.12      0.18       284
#
#     accuracy                           0.95      6554
#    macro avg       0.67      0.56      0.58      6554
# weighted avg       0.94      0.95      0.94      6554
#
# ------------------------------------------------------
#
# FEATURE: weather_related
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.96      0.91      4676
#          1.0       0.86      0.64      0.73      1878
#
#     accuracy                           0.87      6554
#    macro avg       0.86      0.80      0.82      6554
# weighted avg       0.87      0.87      0.86      6554
#
# ------------------------------------------------------
#
# FEATURE: floods
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      6019
#          1.0       0.83      0.54      0.65       535
#
#     accuracy                           0.95      6554
#    macro avg       0.90      0.76      0.81      6554
# weighted avg       0.95      0.95      0.95      6554
#
# ------------------------------------------------------
#
# FEATURE: storm
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97      5911
#          1.0       0.77      0.51      0.61       643
#
#     accuracy                           0.94      6554
#    macro avg       0.86      0.74      0.79      6554
# weighted avg       0.93      0.94      0.93      6554
#
# ------------------------------------------------------
#
# FEATURE: fire
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6479
#          1.0       0.60      0.28      0.38        75
#
#     accuracy                           0.99      6554
#    macro avg       0.80      0.64      0.69      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------------------------------
#
# FEATURE: earthquake
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      5895
#          1.0       0.89      0.75      0.81       659
#
#     accuracy                           0.97      6554
#    macro avg       0.93      0.87      0.90      6554
# weighted avg       0.96      0.97      0.96      6554
#
# ------------------------------------------------------
#
# FEATURE: cold
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6419
#          1.0       0.72      0.41      0.53       135
#
#     accuracy                           0.98      6554
#    macro avg       0.85      0.71      0.76      6554
# weighted avg       0.98      0.98      0.98      6554
#
# ------------------------------------------------------
#
# FEATURE: other_weather
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97      6195
#          1.0       0.49      0.16      0.25       359
#
#     accuracy                           0.94      6554
#    macro avg       0.72      0.58      0.61      6554
# weighted avg       0.93      0.94      0.93      6554
#
# ------------------------------------------------------
#
# FEATURE: direct_report
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92      5279
#          1.0       0.69      0.50      0.58      1275
#
#     accuracy                           0.86      6554
#    macro avg       0.79      0.72      0.75      6554
# weighted avg       0.85      0.86      0.85      6554

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
y_pred_pd = pd.DataFrame(y_pred, columns = y_test.columns)
for column in y_test.columns:
    print('------------------------------------------------------\n')
    print('FEATURE: {}\n'.format(column))
    print(classification_report(y_test[column],y_pred_pd[column]))

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
class VerbExtractor(BaseEstimator, TransformerMixin):

    def verb_extractor(self, text):
        sentence_list = nltk.sent_tokenize(text)
        for sentence in sentence_list:
            pos_tags = nltk.pos_tag(tokenize(sentence))
            first_word, first_tag = pos_tags[0]
            if first_tag in ['VB', 'VBP'] or first_word == 'RT':
                return True
        return False

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.verb_extractor)
        return pd.DataFrame(X_tagged)

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import pickle
filename='clf.sav'
pickle.dump(cv,open(filename,'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
